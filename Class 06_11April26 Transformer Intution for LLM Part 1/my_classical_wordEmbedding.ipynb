# %%
print("AK")
# Out:
# AK

# %%
from gensim.models import Word2Vec, keyedvectors
import gensim.downloader as api

# %% [markdown]
# this model is trained on google news data
# the dimention of this model(Number of neuron in hidden layer)= 300

# %%
model = api.load("word2vec-google-news-300")

# %%
#It is a Embedding
# we try to find out the vector for word "Akshay" 
# 
  
model["Akshay"]
# Out:
# array([-0.0859375 , -0.14453125,  0.05712891,  0.74609375,  0.00646973,
#        -0.125     ,  0.22851562, -0.21875   , -0.06640625,  0.25976562,
#         0.06689453, -0.32421875,  0.10644531, -0.20605469, -0.4921875 ,
#         0.19238281,  0.17089844, -0.24023438, -0.20703125, -0.00778198,
#         0.19433594, -0.02282715,  0.01635742, -0.30859375, -0.00352478,
#        -0.09082031, -0.06103516, -0.2109375 ,  0.34179688, -0.1484375 ,
#        -0.328125  ,  0.0168457 ,  0.18261719,  0.1953125 , -0.20410156,
#        -0.28320312, -0.00473022,  0.24414062,  0.22265625, -0.18457031,
#         0.16796875, -0.09375   , -0.078125  ,  0.32226562,  0.03808594,
#        -0.29492188, -0.15039062,  0.05175781,  0.45507812,  0.15527344,
#         0.06298828, -0.08398438, -0.24023438, -0.0067749 ,  0.11425781,
#        -0.01257324, -0.10888672, -0.24414062, -0.125     , -0.14355469,
#         0.49414062,  0.16015625, -0.2109375 ,  0.22753906, -0.17382812,
# ...

# %%
len(model["Akshay"])
# Out:
# 300

# %%
model["Akshay Kulkarni"]    # only for single word not for sentence or for couple of words
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 model["Akshay Kulkarni"]    # only for single word not for sentence or for couple of words
#
# File e:\Gen AI Bootcamp\Full-Stack-GenerativeAI-And-Agentic-AI-Bootcamp\myenv\Lib\site-packages\gensim\models\keyedvectors.py:403, in KeyedVectors.__getitem__(self, key_or_keys)
#     389 """Get vector representation of `key_or_keys`.
#     390
#     391 Parameters
#    (...)    400
#     401 """
#     402 if isinstance(key_or_keys, _KEY_TYPES):
# --> 403     return self.get_vector(key_or_keys)
#     405 return vstack([self.get_vector(key) for key in key_or_keys])
#
# File e:\Gen AI Bootcamp\Full-Stack-GenerativeAI-And-Agentic-AI-Bootcamp\myenv\Lib\site-packages\gensim\models\keyedvectors.py:446, in KeyedVectors.get_vector(self, key, norm)
#     422 def get_vector(self, key, norm=False):
# ...

# %%
model["men"]
# Out:
# array([-4.78515625e-02,  1.66992188e-01,  7.81250000e-02,  2.10571289e-03,
#         2.25585938e-01, -2.25585938e-01, -2.09960938e-01, -3.73535156e-02,
#        -1.85546875e-02,  1.94335938e-01, -3.00292969e-02, -1.77734375e-01,
#         5.20019531e-02,  1.33789062e-01, -1.13769531e-01,  1.10351562e-01,
#        -3.27148438e-02,  2.89916992e-03,  9.88769531e-03,  9.27734375e-02,
#        -2.19726562e-01, -2.47802734e-02, -8.59375000e-02, -2.67578125e-01,
#        -2.51464844e-02, -2.55859375e-01, -1.61132812e-01,  2.53906250e-01,
#         5.24902344e-02, -1.00097656e-02,  1.82617188e-01,  7.61718750e-02,
#        -1.60980225e-03, -3.10058594e-02, -3.32031250e-02,  1.81640625e-01,
#        -3.88183594e-02, -1.83593750e-01, -8.64257812e-02,  2.20703125e-01,
#        -7.11059570e-03,  8.60595703e-03,  1.73828125e-01, -9.27734375e-02,
#         1.25000000e-01, -1.28906250e-01, -4.85839844e-02, -1.21093750e-01,
# ...

# %%
model.most_similar("king")
